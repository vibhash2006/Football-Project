# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sys

sys.path.append(r"D:\Football Project\src")

from feature_lists import (
    misc_features,
    fw_features,
    availability_features
)

# %%
df=pd.read_csv("../../data/processed/top5leagues_processed_2025.csv")

# %%
df.columns
# Out:
# Index(['league', 'season', 'team', 'player', 'nation', 'pos', 'age', 'born',
#        'Playing Time_MP', 'Playing Time_Starts', 'Playing Time_Min',
#        'Playing Time_90s', 'Performance_Gls', 'Performance_Ast',
#        'Performance_G+A', 'Performance_G-PK', 'Performance_PK',
#        'Performance_PKatt', 'Performance_CrdY', 'Performance_CrdR',
#        'Per 90 Minutes_Gls', 'Per 90 Minutes_Ast', 'Per 90 Minutes_G+A',
#        'Per 90 Minutes_G-PK', 'Per 90 Minutes_G+A-PK', '90s', 'Standard_Gls',
#        'Standard_Sh', 'Standard_SoT', 'Standard_SoT%', 'Standard_Sh/90',
#        'Standard_SoT/90', 'Standard_G/Sh', 'Standard_G/SoT', 'Standard_PK',
#        'Standard_PKatt', 'Starts_Starts', 'Starts_Mn/Start', 'Starts_Compl',
#        'Subs_Subs', 'Subs_Mn/Sub', 'Subs_unSub', 'Team Success_PPM',
#        'Team Success_onG', 'Team Success_onGA', 'Team Success_+/-',
#        'Team Success_+/-90', 'Team Success_On-Off', 'Performance_GA',
#        'Performance_GA90', 'Performance_SoTA', 'Performance_Saves',
#        'Performance_Save%', 'Performance_W', 'Performance_D', 'Performance_L',
#        'Performance_CS', 'Performance_CS%', 'Penalty Kicks_PKatt',
#        'Penalty Kicks_PKA', 'Penalty Kicks_PKsv', 'Penalty Kicks_PKm',
#        'Penalty Kicks_Save%', 'xg', 'xa', 'shots', 'key_passes', 'xg_chain',
#        'xg_buildup', 'goals_minus_xg', 'shot_conversion', 'sot_ratio',
#        'xg_per_shot', 'xa_per_key_pass', 'assist_minus_xa', 'buildup_share',
#        'finishing_share', 'xg_per90', 'xa_per90', 'shots_per90',
#        'key_passes_per90', 'xg_chain_per90', 'xg_buildup_per90'],
#       dtype='str')

# %%
strikers = df[df["pos"].str.contains("FW", na=False)].copy()
strikers = strikers[strikers["Playing Time_Min"] >= 500].copy()
print(len(strikers))
# Out:
# 491

# %% [markdown]
# # Only Considering Players who play a Forward Role and have played meaningful minutes #

# %%
strikers.head()
# Out:
#                 league  season     team              player nation    pos age  \
# 1   ENG-Premier League    2526  Arsenal         Bukayo Saka    ENG  FW,MF  23
# 6   ENG-Premier League    2526  Arsenal        Eberechi Eze    ENG  MF,FW  27
# 10  ENG-Premier League    2526  Arsenal  Gabriel Martinelli    BRA  FW,MF  24
# 12  ENG-Premier League    2526  Arsenal         Kai Havertz    GER  FW,MF  26
# 14  ENG-Premier League    2526  Arsenal    Leandro Trossard    BEL  FW,MF  30
#
#       born  Playing Time_MP  Playing Time_Starts  ...  xa_per_key_pass  \
# 1   2001.0               31                   25  ...         0.137948
# 6   1998.0               32                   21  ...         0.154913
# 10  2001.0               30                   11  ...         0.197629
# 12  1999.0               12                    7  ...         0.132453
# 14  1994.0               31                   21  ...         0.138556
#
#     assist_minus_xa  buildup_share  finishing_share  xg_per90  xa_per90  \
# 1         -3.552798       0.420553         0.455261  0.352275  0.346267
# 6         -0.633517       0.393402         0.464220  0.239177  0.131021
# 10         1.430829       0.359815         0.534463  0.446422  0.214098
# 12         1.543016       0.166219         1.082599  0.753155  0.224151
# 14         1.011992       0.365483         0.497558  0.304197  0.224685
#
#     shots_per90  key_passes_per90  xg_chain_per90  xg_buildup_per90
# 1      2.874494          2.510121        0.773788          0.325419
# 6      3.134328          0.845771        0.515223          0.202690
# 10     2.416667          1.083333        0.835272          0.300543
# 12     2.769231          1.692308        0.695692          0.115637
# 14     2.387387          1.621622        0.611380          0.223449
#
# [5 rows x 83 columns]

# %%
plt.figure(figsize=(10, 5))

plt.hist(
    strikers["goals_minus_xg"],
    bins=20
)

plt.title("Goals Minus xG Distribution")
plt.xlabel("Goals - xG")
plt.ylabel("Number of Players")

plt.show()

# %%
strikers.sort_values(
    "goals_minus_xg",
    ascending=0
)[
    ["player", "team", "Performance_Gls", "xg", "goals_minus_xg"]
].head(5)
# Out:
#                 player          team  Performance_Gls         xg  \
# 2151       Andrej Ilic  Union Berlin                5  11.113925
# 1239   Ludovic Ajorque         Brest                8   9.856391
# 1720  Santiago Hidalgo      Toulouse                4   3.998472
# 1793       Fábio Silva      Dortmund                2   2.105187
# 700   Williot Swedberg    Celta Vigo                5   5.188337
#
#       goals_minus_xg
# 2151       -6.113925
# 1239       -1.856391
# 1720        0.001528
# 1793       -0.105187
# 700        -0.188337

# %%
strikers.sort_values(
    "assist_minus_xa",
    ascending=1
)[
    ["player", "team", "Performance_Ast", "xa", "assist_minus_xa"]
].head(5)
# Out:
#                     player                 team  Performance_Ast         xa  \
# 222            Yeremi Pino       Crystal Palace                2   8.502094
# 2235  Charles De Ketelaere             Atalanta                5  10.652647
# 2525          Kenan Yıldız             Juventus                6  10.820393
# 1911        Jean-Luc Dompé         Hamburger SV                0   4.045239
# 1603       Bradley Barcola  Paris Saint-Germain                1   4.783319
#
#       assist_minus_xa
# 222         -6.502094
# 2235        -5.652647
# 2525        -4.820393
# 1911        -4.045239
# 1603        -3.783319
